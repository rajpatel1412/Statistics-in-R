# %% [markdown]
# Raj Patel. 301383911

# %%
data = read.table(file = "fishdata.txt", header = TRUE)

# %%
head(data)
# Out:
#   Weight Diagonal
# 1 242    4.0200
# 2 290    4.3056
# 3 340    4.6961
# 4 363    4.4555
# 5 430    5.1340
# 6 450    4.9274

# %%
plot(x = data$Diagonal, y = data$Weight, main = "Weight and Length of Fish", xlab = "Diagonal Length (in cm)", 
     ylab = "Weight (in grams)")
# Out:
# Plot with title “Weight and Length of Fish”

# %%
cor(x = data$Diagonal, y = data$Weight)
# Out:
# [1] 0.8865066

# %% [markdown]
# Q1 c) The sample correlation is relatively high an positive and is quite close to one, suggesting a strong positive correlation (hence, a higher weight would indicate a longer length). The correlation assumes the relationship is linear, however, visually, it looks more exponential

# %% [markdown]
# Q1 d) The sample correlation is not the best representation of the relationship between weight and length as the scatterplot suggests a non-linear (possible exponential) relationship (visually). Hence, the number suggeests a strong, positively oriented, linear relationship, however, the case may be that an increase in length would suggest an even higher increase in weight.
